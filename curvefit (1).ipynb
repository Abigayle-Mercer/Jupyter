# %%
import pandas as pd 
from scipy.optimize import curve_fit

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
def logistic(x, midpoint=0, rate=.8, maximum=1):
    return maximum / (1 + np.exp(-rate * (x - midpoint)))

x = np.linspace(-6, 10, 1000)
y = logistic(x)# + logistic(x, midpoint=6, rate=2, maximum=5)



def double_log(x, x1, r1, m1, x2, r2, m2):
    return logistic(x, x1, r1, m1) + logistic(x, x2, r2, m2)


popt1, _ = curve_fit(logistic, x, y , p0=[0,0,0])

popt2, _ = curve_fit(double_log, x, y , p0=[0,0,0,0,0,0])


plt.plot(x, y)
plt.plot(xmodel, ymodel1, 'k')

plt.plot(xmodel, ymodel2, 'r')


from epistasis.stats import pearson

print( pearson(y, ymodel1)**2 )
print( pearson(y, ymodel2)**2 )
# Out:
# 0.9602500194732089
# 0.9602500200201132

# %%
popt1
# Out:
# array([4.82583153e-09, 7.99999999e-01, 1.00000000e+00])

# %%
logistic(50, *popt1)
# Out:
# 1.000000000367842

# %%
x = np.linspace(0,10, 1000)
y = np.cos(x)

plt.plot(x, y)

# %%
y = y**2

# %%
plt.plot(x,y)
